# %%
print('jai sri ram')
# Out:
# jai sri ram

# %% [markdown]
# #importing necessarey libraies for creating automatic text generater in google colab

# %%
#importing necessarey libraries
from transformers import GPT2LMHeadModel,GPT2Tokenizer
import torch

# %% [markdown]
# Load pretrained model and tokenizer

# %%
model_name='gpt2'# You can choose 'gpt2-medium', 'gpt2-large', 'gpt2-xl' for larger models
model=GPT2LMHeadModel.from_pretrained(model_name)
Tokenizer=GPT2Tokenizer.from_pretrained(model_name)

# %% [markdown]
# Define function to generate text based on the prompt given

# %%
def generate_text(prompt,max_length=100):
  inputs=Tokenizer.encode(prompt,return_tensors='pt')
  outputs=model.generate(inputs,max_length=max_length,num_return_sequences=1)
  output_text=Tokenizer.decode(outputs[0],skip_special_tokens=True).strip()
  return output_text

# %% [markdown]
# Test the generatoer

# %%
prompt="United states of america"
generated_text=generate_text(prompt,max_length=100)

print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# United states of america, the United Kingdom, and the United States of America.
#
# The United States of America is a sovereign nation, and the United States of America is a sovereign nation.
#
# The United States of America is a sovereign nation, and the United States of America is a sovereign nation.
#
# The United States of America is a sovereign nation, and the United States of America is a sovereign nation.
#
# The United States of America is a sovereign nation, and the
